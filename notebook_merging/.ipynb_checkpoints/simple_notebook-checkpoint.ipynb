# %%
import numpy as np
import pandas as pd

import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(0,4)
y = np.sin(x)

# %%
p1 = bokeh.plotting.figure(width = 450, height = 350)
p1.line(x,y, line_width = 2)
bokeh.io.show(p1)
# Out:
#   <div class="bk-root" id="454a7695-82f3-4056-8348-838970fe20d2" data-root-id="1229"></div>

# %%
p2 = bokeh.plotting.figure(width = 450, height = 350)
p2.line(y,x, line_width = 2)
bokeh.io.show(p2)
# Out:
#   <div class="bk-root" id="89033c4c-d3f8-4f71-9c4f-8ecec6d5de88" data-root-id="1337"></div>
