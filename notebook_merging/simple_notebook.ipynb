# %%
import numpy as np
import pandas as pd

import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
x = np.linspace(0,5)
y = np.sin(x)

# %%
p1 = bokeh.plotting.figure(width = 450, height = 350)
p1.line(x,y, line_width = 2)
bokeh.io.show(p1)
# Out:
#   <div class="bk-root" id="d0325af7-de7f-47bf-a379-884c3af658b5" data-root-id="1325"></div>

# %%
p2 = bokeh.plotting.figure(width = 450, height = 350)
p2.line(y,x, line_width = 2)
bokeh.io.show(p2)
# Out:
#   <div class="bk-root" id="63bd7035-4c6c-4f33-a324-318ad5809470" data-root-id="1451"></div>

# %%
print('okay')
# Out:
# okay
